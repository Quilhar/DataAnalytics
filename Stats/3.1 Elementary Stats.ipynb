# %%
import data_analytics_lib as dal
import matplotlib.pyplot as plt
import numpy as np  
import pandas as pd

# %% [markdown]
# # Example usages of the library functions

# %%
setx = [3, 5, 6, 8, 12, 2]
data = [24, 25, 26, 27, 30, 32, 40, 44, 50, 52, 55, 57]

# %%
sorted_data = dal.main_stats(setx)
sorted_data['mean']
# Out:
# 6.0

# %%
answer = dal.quartiles(data)
answer['Q1']
# Out:
# 26.75

# %%
dal.histogram(setx, 'X-axis', 'Y-axis', 'Histogram Example', 'blue', 'black')
plt.show()

# %%
dal.piechart(setx, ['A', 'B', 'C', 'D', 'E', 'F'], 'Pie Chart Example', ['red', 'orange', 'yellow', 'green', 'blue', 'purple'], (0.05, 0.05, 0.05, 0.05, 0.05, 0.05), 140, '%1.1f%%')
plt.show()

# %%
dal.boxplot(setx, 'Placeholder', 'Values', 'Box Plot Example', 'lightblue')
plt.show()
