# %%
import numpy as np
import matplotlib.pyplot as plt
import data_analytics_lib as dal
import random
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Needed Dictionaries

# %%
crime_results = {'INCIDENT_NUMBER': ['I182074555', 'I182067317'],
'OFFENSE_CODE': ['00111', '00111'],
'OFFENSE_CODE_GROUP': ['Homicide', 'Homicide'],
'OFFENSE_DESCRIPTION': ['MURDER, NON-NEGLIGIENT MANSLAUGHTER',
'MURDER, NON-NEGLIGIENT MANSLAUGHTER'],
'DISTRICT': ['B2', 'B2'],
'REPORTING_AREA': ['330', '312'],
'SHOOTING': ['Y', 'Y'],
'OCCURRED_ON_DATE': ['2018-09-15 20:10:00', '2018-08-22 15:00:00'],
'YEAR': ['2018', '2018'],
'MONTH': ['9', '8'],
'DAY_OF_WEEK': ['Saturday', 'Wednesday'],
'HOUR': ['20', '15'],
'UCR_PART': ['Part One', 'Part One'],
'STREET': ['BLUE HILL AVE', 'HOLLANDER ST'],
'Lat': [42.30703587, 42.31568920],
'Long': [-71.08410227, -71.08951391],
'Location': ['(42.30703587, -71.08410227)', '(42.31568920, -71.08951391)']}

# districts = {'downtown':['A1', 42.3555, -71.0565], 'charlestown':['A15', 42.3787, -71.0616],
# 'roxbury':['B2', 42.3286, -71.0835], 'mattapan':['B3', 42.2772, -71.0935],
# 'south boston':['C6', 42.3355, -71.0457], 'dorchester':['C11', 42.2995, -71.0649],
# 'south end':['D4', 42.3407, -71.0706], 'brighton':['D14', 42.3489, -71.1605],
# 'west roxbury':['E1', 42.2782, -71.1600], 'jamaica plain':['E13', 42.3132, -71.1141],
# 'hyde park':['E18', 42.2557, -71.1256]}

districts = {'A1': [42.3555, -71.0565], 'A15': [42.3787, -71.0616],
'B2': [42.3286, -71.0835], 'B3': [42.2772, -71.0935],
'C6': [42.3355, -71.0457], 'C11': [42.2995, -71.0649],
'D4': [42.3407, -71.0706], 'D14': [42.3489, -71.1605],
'E1': [42.2782, -71.1600], 'E13': [42.3132, -71.1141],
'E18': [42.2557, -71.1256]}

boston={'lat': 42.3555, 'lon': -71.0565}

# %%
hood = 'B2'
crime = 'Homicide'

district_lat = float(districts[hood][0])
district_lon = float(districts[hood][1])

boston_area = {'lat': district_lat, 'lon': district_lon}

title = f'{crime}s in {hood.capitalize()}'


fig = px.scatter_map(crime_results,
                    lon = 'Long', lat = 'Lat',          # must match keyword in dict or df col
                    hover_data= ['MONTH', 'STREET'],
                    title = title,
                    center = boston_area,
                    zoom = 12,
                    height = 800
                   )

fig.update_layout(mapbox_style="open_street_map")
fig.update_traces(marker = dict(size=10, color='red'))

fig.show()
